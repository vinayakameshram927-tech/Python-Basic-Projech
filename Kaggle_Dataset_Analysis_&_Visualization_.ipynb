# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-043848a4-8770-4ce4-ab69-7f531472e0aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-043848a4-8770-4ce4-ab69-7f531472e0aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_path = '/content/sleep_mental_health.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    student_id  age      gender education_level  avg_sleep_hours  \
# 0           1   21  Non-binary     High School              8.0
# 1           2   19      Female   Undergraduate              7.3
# 2           3   19        Male   Undergraduate              6.1
# 3           4   16        Male     High School              6.2
# 4           5   20        Male        Graduate              5.6
#
#    screen_time_hours  social_media_hours  study_hours_per_day  \
# 0                4.9                 3.7                  5.0
# 1                7.7                 5.3                  2.8
# 2                7.3                 3.6                  3.6
# 3                7.4                 4.0                  0.4
# 4               12.5                 8.3                  2.6
#
#    exercise_hours_per_week  caffeine_drinks_per_day  stress_level  \
# 0                      4.8                        1             7
# 1                      4.2                        1             8
# ...

# %%
df.shape
# Out:
# (3000, 15)

# %%
df.dtypes
# Out:
# student_id                   int64
# age                          int64
# gender                      object
# education_level             object
# avg_sleep_hours            float64
# screen_time_hours          float64
# social_media_hours         float64
# study_hours_per_day        float64
# exercise_hours_per_week    float64
# caffeine_drinks_per_day      int64
# stress_level                 int64
# anxiety_score                int64
# gpa                        float64
# uses_sleep_app                bool
# feels_burned_out              bool
# dtype: object

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'education_level', 'avg_sleep_hours',
#        'screen_time_hours', 'social_media_hours', 'study_hours_per_day',
#        'exercise_hours_per_week', 'caffeine_drinks_per_day', 'stress_level',
#        'anxiety_score', 'gpa', 'uses_sleep_app', 'feels_burned_out'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# student_id                 0
# age                        0
# gender                     0
# education_level            0
# avg_sleep_hours            0
# screen_time_hours          0
# social_media_hours         0
# study_hours_per_day        0
# exercise_hours_per_week    0
# caffeine_drinks_per_day    0
# stress_level               0
# anxiety_score              0
# gpa                        0
# uses_sleep_app             0
# feels_burned_out           0
# dtype: int64

# %%
df.describe()
# Out:
#         student_id          age  avg_sleep_hours  screen_time_hours  \
# count  3000.000000  3000.000000      3000.000000        3000.000000
# mean   1500.500000    19.445000         7.414067           6.494667
# std     866.169729     2.924921         0.971279           2.165014
# min       1.000000    14.000000         4.400000           1.000000
# 25%     750.750000    17.000000         6.800000           5.000000
# 50%    1500.500000    19.000000         7.400000           6.500000
# 75%    2250.250000    21.000000         8.100000           8.000000
# max    3000.000000    29.000000        10.900000          13.600000
#
#        social_media_hours  study_hours_per_day  exercise_hours_per_week  \
# count         3000.000000          3000.000000              3000.000000
# mean             3.575033             3.235200                 3.541900
# std              1.563631             1.405491                 2.336889
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head()
# Out:
#    student_id  age      gender education_level  avg_sleep_hours  \
# 0           1   21  Non-binary     High School              8.0
# 1           2   19      Female   Undergraduate              7.3
# 2           3   19        Male   Undergraduate              6.1
# 3           4   16        Male     High School              6.2
# 4           5   20        Male        Graduate              5.6
#
#    screen_time_hours  social_media_hours  study_hours_per_day  \
# 0                4.9                 3.7                  5.0
# 1                7.7                 5.3                  2.8
# 2                7.3                 3.6                  3.6
# 3                7.4                 4.0                  0.4
# 4               12.5                 8.3                  2.6
#
#    exercise_hours_per_week  caffeine_drinks_per_day  stress_level  \
# 0                      4.8                        1             7
# 1                      4.2                        1             8
# ...

# %%
sns.histplot(df['education_level'])
# Out:
# <Axes: xlabel='education_level', ylabel='Count'>

# %%
sns.boxplot(x = df['avg_sleep_hours'],y = df['education_level'])
# Out:
# <Axes: xlabel='avg_sleep_hours', ylabel='education_level'>

# %%
sns.scatterplot(x = df['study_hours_per_day'], y = df['avg_sleep_hours'])
# Out:
# <Axes: xlabel='study_hours_per_day', ylabel='avg_sleep_hours'>

# %%
sns.heatmap(df.corr(numeric_only = True))
# Out:
# <Axes: >

# %%
sns.countplot(x = df['stress_level'],hue = df['uses_sleep_app'])
# Out:
# <Axes: xlabel='stress_level', ylabel='count'>

# %%
'''
Summary :-
          The Student Sleep, Screen Time and Mental Health 2026 dataset contains student lifestyle and well-being information,
          focusing on how sleep habits and daily screen time relate to mental health outcomes. It includes demographic,
          behavioral, and mental health variables that can be used to explore patterns affecting student wellness and academic
          life. The dataset is suitable for exploratory data analysis (EDA), data visualization, and machine learning projects
          such as predicting stress or mental health risk.

Key Insights :-
          1. Higher screen time is linked to higher stress.
          2. 7–9 hours of sleep is associated with better mental health.
          3. Less sleep is linked to increased anxiety and stress.
          4. More screen time often means less sleep.
          5. Healthy sleep habits and limited screen time are associated with better well-being.
'''
# Out:
# '\nSummary :-\n          The Student Sleep, Screen Time and Mental Health 2026 dataset contains student lifestyle and well-being information,\n          focusing on how sleep habits and daily screen time relate to mental health outcomes. It includes demographic,\n          behavioral, and mental health variables that can be used to explore patterns affecting student wellness and academic\n          life. The dataset is suitable for exploratory data analysis (EDA), data visualization, and machine learning projects\n          such as predicting stress or mental health risk.\n\nKey Insights :-\n          1. Higher screen time is linked to higher stress.\n          2. 7–9 hours of sleep is associated with better mental health.\n          3. Less sleep is linked to increased anxiety and stress.\n          4. More screen time often means less sleep.\n          5. Healthy sleep habits and limited screen time are associated with better well-being.\n'
