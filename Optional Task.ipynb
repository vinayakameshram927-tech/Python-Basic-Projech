# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-a1c99b0e-074b-44da-987d-f38dc81419e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1c99b0e-074b-44da-987d-f38dc81419e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_path = '/content/ai_student_impact_dataset.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# ...

# %%
df.tail()
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 49995               12.16       Copywriting/Drafting                 Beginner
# 49996                2.51       Copywriting/Drafting             Intermediate
# 49997               15.87        Summarizing_Reading                 Advanced
# 49998               19.91  Debugging/Troubleshooting             Intermediate
# 49999                3.30       Copywriting/Drafting                 Beginner
#
#        Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# ...

# %%
df.shape
# Out:
# (50000, 16)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Major_Category', 'Year_of_Study', 'Pre_Semester_GPA',
#        'Weekly_GenAI_Hours', 'Primary_Use_Case', 'Prompt_Engineering_Skill',
#        'Tool_Diversity', 'Paid_Subscription', 'Traditional_Study_Hours',
#        'Perceived_AI_Dependency', 'Institutional_Policy',
#        'Anxiety_Level_During_Exams', 'Post_Semester_GPA',
#        'Skill_Retention_Score', 'Burnout_Risk_Level'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  50000 non-null  int64
#  1   Major_Category              50000 non-null  object
#  2   Year_of_Study               50000 non-null  object
#  3   Pre_Semester_GPA            50000 non-null  float64
#  4   Weekly_GenAI_Hours          50000 non-null  float64
#  5   Primary_Use_Case            50000 non-null  object
#  6   Prompt_Engineering_Skill    50000 non-null  object
#  7   Tool_Diversity              50000 non-null  int64
#  8   Paid_Subscription           50000 non-null  bool
#  9   Traditional_Study_Hours     50000 non-null  float64
#  10  Perceived_AI_Dependency     50000 non-null  int64
#  11  Institutional_Policy        50000 non-null  object
#  12  Anxiety_Level_During_Exams  50000 non-null  int64
# ...

# %%
df.describe()
# Out:
#           Student_ID  Pre_Semester_GPA  Weekly_GenAI_Hours  Tool_Diversity  \
# count   50000.000000      50000.000000        50000.000000     50000.00000
# mean   125000.500000          3.146102            8.427752         2.80026
# std     14433.901067          0.478854            8.269490         1.18802
# min    100001.000000          1.183000            0.000000         1.00000
# 25%    112500.750000          2.834000            2.390000         2.00000
# 50%    125000.500000          3.210000            5.800000         3.00000
# 75%    137500.250000          3.521000           11.720000         4.00000
# max    150000.000000          3.998000           40.000000         5.00000
#
#        Traditional_Study_Hours  Perceived_AI_Dependency  \
# count             50000.000000             50000.000000
# mean                 11.209271                 3.505360
# std                   5.156426                 1.820812
# min                   1.000000                 1.000000
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                    0
# Major_Category                0
# Year_of_Study                 0
# Pre_Semester_GPA              0
# Weekly_GenAI_Hours            0
# Primary_Use_Case              0
# Prompt_Engineering_Skill      0
# Tool_Diversity                0
# Paid_Subscription             0
# Traditional_Study_Hours       0
# Perceived_AI_Dependency       0
# Institutional_Policy          0
# Anxiety_Level_During_Exams    0
# Post_Semester_GPA             0
# Skill_Retention_Score         0
# Burnout_Risk_Level            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Numerical Columns: ")
df.select_dtypes(include = 'number')
# Out:
# Numerical Columns:
#        Student_ID  Pre_Semester_GPA  Weekly_GenAI_Hours  Tool_Diversity  \
# 0          100001             2.418               23.31               1
# 1          100002             3.821                1.12               5
# 2          100003             3.398               21.26               2
# 3          100004             3.789                1.82               4
# 4          100005             3.635                9.29               4
# ...           ...               ...                 ...             ...
# 49995      149996             2.899               12.16               2
# 49996      149997             2.870                2.51               1
# 49997      149998             3.177               15.87               5
# 49998      149999             3.398               19.91               5
# 49999      150000             3.242                3.30               1
#
#        Traditional_Study_Hours  Perceived_AI_Dependency  \
# ...

# %%
print("Categorical Columns: ")
df.select_dtypes(include = 'object')
# Out:
# Categorical Columns:
#       Major_Category Year_of_Study           Primary_Use_Case  \
# 0         Humanities        Senior       Copywriting/Drafting
# 1            Medical        Junior                   Ideation
# 2           Business      Freshman        Summarizing_Reading
# 3           Business        Senior       Copywriting/Drafting
# 4               STEM     Sophomore  Debugging/Troubleshooting
# ...              ...           ...                        ...
# 49995       Business        Senior       Copywriting/Drafting
# 49996           STEM        Senior       Copywriting/Drafting
# 49997       Business        Senior        Summarizing_Reading
# 49998       Business        Junior  Debugging/Troubleshooting
# 49999           Arts     Sophomore       Copywriting/Drafting
#
#       Prompt_Engineering_Skill   Institutional_Policy Burnout_Risk_Level
# 0                     Beginner  Allowed_With_Citation               High
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['Major_Category'])
# Out:
# <Axes: xlabel='Major_Category', ylabel='Count'>

# %%
sns.countplot(x = df['Prompt_Engineering_Skill'],data= df)
# Out:
# <Axes: xlabel='Prompt_Engineering_Skill', ylabel='count'>

# %%
sns.heatmap(df.corr(numeric_only = True))
# Out:
# <Axes: >

# %%
sns.boxplot(x = 'Year_of_Study', y = 'Pre_Semester_GPA', data = df)
# Out:
# <Axes: xlabel='Year_of_Study', ylabel='Pre_Semester_GPA'>

# %%
df.head()
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# ...

# %%
sns.scatterplot(x = 'Post_Semester_GPA', y = 'Skill_Retention_Score', data = df)
# Out:
# <Axes: xlabel='Post_Semester_GPA', ylabel='Skill_Retention_Score'>

# %%
avg_Skill_retention_score = df['Skill_Retention_Score'].mean()
print("Average Skill Retention Score:",avg_Skill_retention_score)
# Out:
# Average Skill Retention Score: 75.798125

# %%
minimum = df['Skill_Retention_Score'].min()
maximum = df['Skill_Retention_Score'].max()
print("Minimum Skill Retention Score:",minimum)
print("Maximum Skill Retention Score:",maximum)
# Out:
# Minimum Skill Retention Score: 10.78
# Maximum Skill Retention Score: 100.0

# %%
'''Short Summery
This is a synthetic dataset on how generative AI use affects college students — 50,000 records, 16 columns, no missing data.
It tracks each student's major, year, and AI habits (weekly usage hours, main use case, prompt skill level, tool variety,
paid subscriptions, campus AI policy) alongside outcomes: GPA before/after the semester, study hours, skill retention,
AI dependency, exam anxiety, and burnout risk.
In short: it's built to explore how AI usage patterns relate to academic performance and student wellbeing.'''
